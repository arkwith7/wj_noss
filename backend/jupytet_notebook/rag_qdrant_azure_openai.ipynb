# %% [markdown]
# # RAG 개발: PDF 청킹, Qdrant 적재, Azure OpenAI 검색
# 이 노트북은 PDF 파일을 청킹하여 Qdrant에 임베딩을 저장하고, Azure OpenAI를 활용해 검색하는 전체 과정을 다룹니다.
#
# ## 절차
# 1. 필수 라이브러리 설치
# 2. 환경 변수 및 라이브러리 임포트
# 3. PDF 파일 로드 및 청킹
# 4. Azure OpenAI 임베딩 객체 생성
# 5. Qdrant에 임베딩 및 문서 저장
# 6. Qdrant에서 유사도 검색

# %%
# 1. 필수 라이브러리 설치
# !pip install PyPDF2 pypdf qdrant-client requests tqdm langchain-community langchain-openai python-dotenv
# Out:
# Requirement already satisfied: PyPDF2 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (3.0.1)
# Requirement already satisfied: pypdf in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (5.6.0)
# Requirement already satisfied: qdrant-client in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (1.14.2)
# Requirement already satisfied: requests in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (2.32.3)
# Requirement already satisfied: tqdm in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (4.66.5)
# Requirement already satisfied: langchain-community in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (0.3.24)
# Requirement already satisfied: langchain-openai in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (0.3.21)
# Requirement already satisfied: python-dotenv in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (1.1.0)
# Requirement already satisfied: grpcio>=1.41.0 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from qdrant-client) (1.66.2)
# Requirement already satisfied: httpx>=0.20.0 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from httpx[http2]>=0.20.0->qdrant-client) (0.28.1)
# Requirement already satisfied: numpy>=1.21 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from qdrant-client) (2.2.6)
# Requirement already satisfied: portalocker<3.0.0,>=2.7.0 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from qdrant-client) (2.10.1)
# Requirement already satisfied: protobuf>=3.20.0 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from qdrant-client) (5.28.2)
# Requirement already satisfied: pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from qdrant-client) (2.9.2)
# Requirement already satisfied: urllib3<3,>=1.26.14 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from qdrant-client) (2.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from requests) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from requests) (2024.8.30)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.59 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from langchain-community) (0.3.64)
# Requirement already satisfied: langchain<1.0.0,>=0.3.25 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from langchain-community) (0.3.25)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from langchain-community) (2.0.41)
# Requirement already satisfied: PyYAML>=5.3 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from langchain-community) (3.12.9)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from langchain-community) (2.9.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from langchain-community) (0.3.45)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.6.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from langchain<1.0.0,>=0.3.25->langchain-community) (0.3.8)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.59->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.59->langchain-community) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.59->langchain-community) (4.12.2)
# Requirement already satisfied: jsonpointer>=1.9 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.59->langchain-community) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: anyio in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8->qdrant-client) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8->qdrant-client) (2.23.4)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.59 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from langchain-community) (0.3.64)
# Requirement already satisfied: langchain<1.0.0,>=0.3.25 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from langchain-community) (0.3.25)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from langchain-community) (2.0.41)
# Requirement already satisfied: PyYAML>=5.3 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from langchain-community) (3.12.9)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from langchain-community) (2.9.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from langchain-community) (0.3.45)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.6.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from langchain<1.0.0,>=0.3.25->langchain-community) (0.3.8)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.59->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.59->langchain-community) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.59->langchain-community) (4.12.2)
# Requirement already satisfied: jsonpointer>=1.9 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.59->langchain-community) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: anyio in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8->qdrant-client) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8->qdrant-client) (2.23.4)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (0.4.1)
# Requirement already satisfied: greenlet>=1 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.2.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.1.0)
# Requirement already satisfied: openai<2.0.0,>=1.68.2 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from langchain-openai) (1.84.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from langchain-openai) (0.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (0.10.0)
# Requirement already satisfied: sniffio in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (1.3.1)
# Requirement already satisfied: regex>=2022.1.18 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.11.6)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (0.4.1)
# Requirement already satisfied: greenlet>=1 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.2.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.1.0)
# Requirement already satisfied: openai<2.0.0,>=1.68.2 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from langchain-openai) (1.84.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from langchain-openai) (0.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (0.10.0)
# Requirement already satisfied: sniffio in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (1.3.1)
# Requirement already satisfied: regex>=2022.1.18 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.11.6)
# Requirement already satisfied: h2<5,>=3 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from httpx[http2]>=0.20.0->qdrant-client) (4.2.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client) (4.1.0)
# Requirement already satisfied: h2<5,>=3 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from httpx[http2]>=0.20.0->qdrant-client) (4.2.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /home/wjadmin/Dev/wj_noss/venv/lib/python3.11/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client) (4.1.0)

# %%
# 2. 환경 변수 및 라이브러리 임포트
import os
from dotenv import load_dotenv
from langchain_community.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_openai import AzureOpenAIEmbeddings
from langchain_community.vectorstores import Qdrant

# .env 파일 로드 및 환경 변수 설정
load_dotenv("../.env")
AZURE_OPENAI_ENDPOINT = os.getenv("AZURE_OPENAI_ENDPOINT")
AZURE_OPENAI_API_KEY = os.getenv("AZURE_OPENAI_API_KEY")
AZURE_OPENAI_EMBEDDING_DEPLOYMENT = os.getenv("AZURE_OPENAI_EMBEDDING_DEPLOYMENT")
QDRANT_URL = os.getenv("QDRANT_URL")
PDF_PATH = "../upload/folder/NOSS - P853.002.4.2021 - TVET Instuction - Complete.pdf"

print(f"QDRANT_URL: {QDRANT_URL}")
if QDRANT_URL and ("qdrant:6333" in QDRANT_URL):
    print("경고: QDRANT_URL이 'qdrant:6333'으로 되어 있습니다. 노트북에서 Qdrant에 접근하려면 반드시 'http://localhost:6333'으로 설정해야 합니다! .env 파일을 수정하세요.")
# Out:
# QDRANT_URL: http://localhost:6333

# %% [markdown]
# ## PDF 파일 로드 및 청킹
# PDF 파일을 불러와서 텍스트를 일정 길이로 청킹합니다.

# %%
# 3. PDF 파일 로드 및 텍스트 청킹
# PDF 파일을 LangChain의 PyPDFLoader로 불러오고, RecursiveCharacterTextSplitter로 텍스트를 청킹합니다.
loader = PyPDFLoader(PDF_PATH)
documents = loader.load()
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
docs = text_splitter.split_documents(documents)
print(f"총 청크 개수: {len(docs)}")
print(f"첫 번째 청크 예시:\n{docs[0].page_content[:300]}")
# Out:
# 총 청크 개수: 388
# 첫 번째 청크 예시:
# Jabatan Pembangunan Kemahiran
# Kementerian Sumber Manusia, Malaysia
#
#
# NATIONAL OCCUPATIONAL SKILLS STANDARD
# (STANDARD KEMAHIRAN PEKERJAAN KEBANGSAAN)
#
#
#
#
#
# P853-002-4:2021
#
# TVET INSTRUCTION
#
# PENGAJARAN TVET
#
# LEVEL 4

# %% [markdown]
# ## Azure OpenAI 임베딩 생성
# 각 청크에 대해 Azure OpenAI의 text-embedding-ada-002 모델을 사용해 임베딩을 생성합니다.

# %%
# 필요한 라이브러리 임포트
from langchain_openai import AzureOpenAIEmbeddings
from langchain_community.vectorstores import Qdrant
# from langchain.embeddings import AzureOpenAIEmbeddings
# from langchain.vectorstores import Qdrant
from tqdm import tqdm

# Azure OpenAI 임베딩 생성 함수 (직접 API 호출 - 선택사항)
def get_embedding_azure_openai(text, endpoint, api_key, deployment):
    """
    Azure OpenAI API를 직접 호출하여 임베딩 생성
    (LangChain 사용시에는 불필요)
    """
    url = f"{endpoint}/openai/deployments/{deployment}/embeddings?api-version=2025-01-01-preview"
    headers = {
        "Content-Type": "application/json",
        "api-key": api_key
    }
    data = {
        "input": text,
        "model": deployment
    }
    response = requests.post(url, headers=headers, json=data)
    response.raise_for_status()
    return response.json()["data"][0]["embedding"]

# Qdrant URL 점검 및 안내
print(f"QDRANT_URL: {QDRANT_URL}")
if QDRANT_URL and ("qdrant:6333" in QDRANT_URL):
    print("경고: QDRANT_URL이 'qdrant:6333'으로 되어 있습니다. 노트북에서 Qdrant에 접근하려면 반드시 'http://localhost:6333'으로 설정해야 합니다! .env 파일을 수정하세요.")

# 4. Azure OpenAI 임베딩 객체 생성
# LangChain의 AzureOpenAIEmbeddings를 사용해 임베딩 객체를 생성합니다.
embeddings = AzureOpenAIEmbeddings(
    azure_endpoint=AZURE_OPENAI_ENDPOINT,
    api_key=AZURE_OPENAI_API_KEY,
    azure_deployment=AZURE_OPENAI_EMBEDDING_DEPLOYMENT,
    api_version="2025-01-01-preview",
    chunk_size=1000
)

# docs 변수가 미리 정의되어 있어야 함
# 예: docs = [Document(page_content="...", metadata={...}), ...]

# Qdrant VectorStore에 임베딩 및 문서 저장
if 'docs' in locals() and docs:  # docs 변수 존재 확인
    qdrant = Qdrant.from_documents(
        docs,
        embeddings,
        url=QDRANT_URL,
        collection_name="rag_chunks"
    )
    print(f"Qdrant에 {len(docs)}개 청크 임베딩 저장 완료.")
else:
    print("오류: 'docs' 변수가 정의되지 않았습니다.")
# Out:
# https://hspar-m7k2pfor-swedencentral.openai.azure.com/
# FYKi43LLv1e3BWFkQpKT4QiTc7dzbhkZ0r1kV3CimDz8iRDWy854JQQJ99BBACfhMk5XJ3w3AAAAACOGRdJz
# text-embedding-ada-002
# QDRANT_URL: http://localhost:6333
# Qdrant에 388개 청크 임베딩 저장 완료.
# Qdrant에 388개 청크 임베딩 저장 완료.

# %% [markdown]
# ## Qdrant에 임베딩 저장
# 생성된 임베딩을 Qdrant에 저장합니다. 컬렉션이 없으면 생성합니다.

# %%
# docs에서 텍스트만 추출하여 chunks 리스트 생성
chunks = [doc.page_content for doc in docs]

# Qdrant에 임베딩 저장 함수
def upsert_embeddings_to_qdrant(embeddings, chunks, qdrant_url, collection_name="rag_chunks", vector_size=1536):
    client = QdrantClient(url=qdrant_url)
    # 컬렉션 생성 (존재하지 않으면)
    if collection_name not in [c.name for c in client.get_collections().collections]:
        client.recreate_collection(
            collection_name=collection_name,
            vectors_config=models.VectorParams(size=vector_size, distance=models.Distance.COSINE)
        )
    # 포인트 업서트
    points = []
    for i, (emb, chunk) in enumerate(zip(embeddings, chunks)):
        points.append(models.PointStruct(
            id=str(uuid.uuid4()),
            vector=emb,
            payload={"text": chunk, "chunk_id": i}
        ))
    client.upsert(collection_name=collection_name, points=points)
    print(f"Qdrant에 {len(points)}개 임베딩 저장 완료.")

# 5. Qdrant에 임베딩 및 문서 저장
# LangChain Qdrant VectorStore를 사용해 임베딩과 문서를 Qdrant에 저장합니다.
if docs:
    qdrant = Qdrant.from_documents(
        docs,
        embeddings,
        url=QDRANT_URL,
        collection_name="rag_chunks"
    )
    print(f"Qdrant에 {len(docs)}개 청크 임베딩 저장 완료.")
else:
    print("오류: docs 리스트가 비어 있습니다.")
# Out:
# Qdrant에 388개 청크 임베딩 저장 완료.

# %% [markdown]
# ## Qdrant 검색 및 결과 확인
# 사용자 쿼리를 임베딩하여 Qdrant에서 유사한 청크를 검색합니다.

# %%
# 6. Qdrant에서 유사도 검색
# 사용자가 입력한 쿼리를 임베딩하여 Qdrant에서 유사한 청크를 검색합니다.
user_query = "이 문서의 주요 목적은 무엇인가요?"
if 'qdrant' in locals():
    results = qdrant.similarity_search(user_query, k=5)
    for i, doc in enumerate(results, 1):
        print(f"[{i}] {doc.page_content[:300]}")
        print("-"*60)
else:
    print("Qdrant 인스턴스가 없습니다. 이전 셀을 먼저 실행하세요.")
# Out:
# [1] TABLE OF CONTENTS
# Preface ....................................................................................................................................... i
# Abbreviation .........................................................................................................................
# ------------------------------------------------------------
# [2] TABLE OF CONTENTS
# Preface ....................................................................................................................................... i
# Abbreviation .........................................................................................................................
# ------------------------------------------------------------
# [3] TABLE OF CONTENTS
# Preface ....................................................................................................................................... i
# Abbreviation .........................................................................................................................
# ------------------------------------------------------------
# [4] TABLE OF CONTENTS
# Preface ....................................................................................................................................... i
# Abbreviation .........................................................................................................................
# ------------------------------------------------------------
# [5] 7.2 Specify related sub-
# topic.
# 7.3 Acquire overall
# content should meet
# ATTITUDE
# 7.1 Ensure systematic
# documentation.
# 7.2 Adhere to
# continuous
# effective learning.
# 7.1 Overview of Information
# Sheet explained.
# 7.2 Source of instructional
# material highlighted.
# 7.3 References to CoCU
# liste
# ------------------------------------------------------------
